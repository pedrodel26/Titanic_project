# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.head(11)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S

# %%
data.tail(11)
# Out:
#      PassengerId  Survived  Pclass  \
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 881                            Markun, Mr. Johann    male  33.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 884                        Sutehall, Mr. Henry Jr    male  25.0      0      0
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                         Behr, Mr. Karl Howell    male  26.0      0      0
# 890                           Dooley, Mr. Patrick    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 880            230433  26.0000   NaN        S
# 881            349257   7.8958   NaN        S
# 882              7552  10.5167   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 885            382652  29.1250   NaN        Q
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
# 889            111369  30.0000  C148        C
# 890            370376   7.7500   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Nome    Sexo   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.rename({'Name': 'Nome', 'Sex': 'Sexo'}, axis=1, inplace=True)

# %%
data.rename({'Name': 'Nome', 'Sex': 'Sexo'}, axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Nome', 'Sexo', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.columns = ['IdPassageiro', 'Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade', 'IrmaosConjugue',
       'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']

# %%
data.head(2)
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
#
#    IrmaosConjugue  PaisFilhos    Bilhete  Taarifa Cabine Embarque
# 0               1           0  A/5 21171   7.2500    NaN        S
# 1               1           0   PC 17599  71.2833    C85        C

# %%
data[['Nome', 'Sexo', 'Classe', 'Tarifa', 'Idade', 'Sobreviveu']].head(50)
# Out:
#                                                  Nome    Sexo  Classe  \
# 0                             Braund, Mr. Owen Harris    male       3
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 2                              Heikkinen, Miss. Laina  female       3
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 4                            Allen, Mr. William Henry    male       3
# 5                                    Moran, Mr. James    male       3
# 6                             McCarthy, Mr. Timothy J    male       1
# 7                      Palsson, Master. Gosta Leonard    male       3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female       3
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female       2
# 10                    Sandstrom, Miss. Marguerite Rut  female       3
# 11                           Bonnell, Miss. Elizabeth  female       1
# 12                     Saundercock, Mr. William Henry    male       3
# 13                        Andersson, Mr. Anders Johan    male       3
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female       3
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female       2
# 16                               Rice, Master. Eugene    male       3
# 17                       Williams, Mr. Charles Eugene    male       2
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female       3
# 19                            Masselmani, Mrs. Fatima  female       3
# 20                               Fynney, Mr. Joseph J    male       2
# 21                              Beesley, Mr. Lawrence    male       2
# 22                        McGowan, Miss. Anna "Annie"  female       3
# 23                       Sloper, Mr. William Thompson    male       1
# 24                      Palsson, Miss. Torborg Danira  female       3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female       3
# 26                            Emir, Mr. Farred Chehab    male       3
# 27                     Fortune, Mr. Charles Alexander    male       1
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female       3
# 29                                Todoroff, Mr. Lalio    male       3
# 30                           Uruchurtu, Don. Manuel E    male       1
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female       1
# 32                           Glynn, Miss. Mary Agatha  female       3
# 33                              Wheadon, Mr. Edward H    male       2
# 34                            Meyer, Mr. Edgar Joseph    male       1
# 35                     Holverson, Mr. Alexander Oskar    male       1
# 36                                   Mamee, Mr. Hanna    male       3
# 37                           Cann, Mr. Ernest Charles    male       3
# 38                 Vander Planke, Miss. Augusta Maria  female       3
# 39                        Nicola-Yarred, Miss. Jamila  female       3
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female       3
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female       2
# 42                                Kraeff, Mr. Theodor    male       3
# 43           Laroche, Miss. Simonne Marie Anne Andree  female       2
# 44                      Devaney, Miss. Margaret Delia  female       3
# 45                           Rogers, Mr. William John    male       3
# 46                                  Lennon, Mr. Denis    male       3
# 47                          O'Driscoll, Miss. Bridget  female       3
# 48                                Samaan, Mr. Youssef    male       3
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female       3
#
#       Tarifa  Idade  Sobreviveu
# 0     7.2500   22.0           0
# 1    71.2833   38.0           1
# 2     7.9250   26.0           1
# 3    53.1000   35.0           1
# 4     8.0500   35.0           0
# 5     8.4583    NaN           0
# 6    51.8625   54.0           0
# 7    21.0750    2.0           0
# 8    11.1333   27.0           1
# 9    30.0708   14.0           1
# 10   16.7000    4.0           1
# 11   26.5500   58.0           1
# 12    8.0500   20.0           0
# 13   31.2750   39.0           0
# 14    7.8542   14.0           0
# 15   16.0000   55.0           1
# 16   29.1250    2.0           0
# 17   13.0000    NaN           1
# 18   18.0000   31.0           0
# 19    7.2250    NaN           1
# 20   26.0000   35.0           0
# 21   13.0000   34.0           1
# 22    8.0292   15.0           1
# 23   35.5000   28.0           1
# 24   21.0750    8.0           0
# 25   31.3875   38.0           1
# 26    7.2250    NaN           0
# 27  263.0000   19.0           0
# 28    7.8792    NaN           1
# 29    7.8958    NaN           0
# 30   27.7208   40.0           0
# 31  146.5208    NaN           1
# 32    7.7500    NaN           1
# 33   10.5000   66.0           0
# 34   82.1708   28.0           0
# 35   52.0000   42.0           0
# 36    7.2292    NaN           1
# 37    8.0500   21.0           0
# 38   18.0000   18.0           0
# 39   11.2417   14.0           1
# 40    9.4750   40.0           0
# 41   21.0000   27.0           0
# 42    7.8958    NaN           0
# 43   41.5792    3.0           1
# 44    7.8792   19.0           1
# 45    8.0500    NaN           0
# 46   15.5000    NaN           0
# 47    7.7500    NaN           1
# 48   21.6792    NaN           0
# 49   17.8000   18.0           0

# %%
data[['Sexo']]
# Out:
#        Sexo
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# ..      ...
# 886    male
# 887  female
# 888  female
# 889    male
# 890    male
#
# [891 rows x 1 columns]

# %%
data['Sexo']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sexo, Length: 891, dtype: object

# %%
data['Idade']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Idade, Length: 891, dtype: float64

# %%
data['Idade'].mean()
# Out:
# 29.69911764705882

# %%
data['Idade'].sum()
# Out:
# 21205.17

# %%
data['Idade'].count()
# Out:
# 714

# %%
data['Idade'].median()
# Out:
# 28.0

# %%
data['Idade'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
data['Idade'].max()
# Out:
# 80.0

# %%
data['Idade'].min()
# Out:
# 0.42

# %%
data['Idade'].idxmin()
# Out:
# 803

# %%
data['Idade'].idxmax()
# Out:
# 630

# %%
data.mean()
# Out:
# IdPassageiro      446.000000
# Sobreviveu          0.383838
# Classe              2.308642
# Idade              29.699118
# IrmaosConjugue      0.523008
# PaisFilhos          0.381594
# Tarifa             32.204208
# dtype: float64

# %%
data.sum()
# Out:
# IdPassageiro                                                 397386
# Sobreviveu                                                      342
# Classe                                                         2057
# Nome              Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sexo              malefemalefemalefemalemalemalemalemalefemalefe...
# Idade                                                      21205.17
# IrmaosConjugue                                                  466
# PaisFilhos                                                      340
# Bilhete           A/5 21171PC 17599STON/O2. 31012821138033734503...
# Tarifa                                                   28693.9493
# dtype: object

# %% [markdown]
# Iloc

# %%
data.iloc[630]
# Out:
# IdPassageiro                                       631
# Sobreviveu                                           1
# Classe                                               1
# Nome              Barkworth, Mr. Algernon Henry Wilson
# Sexo                                              male
# Idade                                             80.0
# IrmaosConjugue                                       0
# PaisFilhos                                           0
# Bilhete                                          27042
# Tarifa                                            30.0
# Cabine                                             A23
# Embarque                                             S
# Name: 630, dtype: object

# %%
data.iloc[803]
# Out:
# IdPassageiro                                  804
# Sobreviveu                                      1
# Classe                                          3
# Nome              Thomas, Master. Assad Alexander
# Sexo                                         male
# Idade                                        0.42
# IrmaosConjugue                                  0
# PaisFilhos                                      1
# Bilhete                                      2625
# Tarifa                                     8.5167
# Cabine                                        NaN
# Embarque                                        C
# Name: 803, dtype: object

# %%
data.iloc[[803]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                             Nome  Sexo  \
# 803           804           1       3  Thomas, Master. Assad Alexander  male
#
#      Idade  IrmaosConjugue  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 803   0.42               0           1    2625  8.5167    NaN        C

# %%
data.iloc[[630]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
#
#      Sexo  Idade  IrmaosConjugue  PaisFilhos Bilhete  Tarifa Cabine Embarque
# 630  male   80.0               0           0   27042    30.0    A23        S

# %%
data.iloc[32]
# Out:
# IdPassageiro                            33
# Sobreviveu                               1
# Classe                                   3
# Nome              Glynn, Miss. Mary Agatha
# Sexo                                female
# Idade                                  NaN
# IrmaosConjugue                           0
# PaisFilhos                               0
# Bilhete                             335677
# Tarifa                                7.75
# Cabine                                 NaN
# Embarque                                 Q
# Name: 32, dtype: object

# %%
data.iloc[[630,70,803,80]]
# Out:
#      IdPassageiro  Sobreviveu  Classe                                  Nome  \
# 630           631           1       1  Barkworth, Mr. Algernon Henry Wilson
# 70             71           0       2            Jenkin, Mr. Stephen Curnow
# 803           804           1       3       Thomas, Master. Assad Alexander
# 80             81           0       3                  Waelens, Mr. Achille
#
#      Sexo  Idade  IrmaosConjugue  PaisFilhos     Bilhete   Tarifa Cabine  \
# 630  male  80.00               0           0       27042  30.0000    A23
# 70   male  32.00               0           0  C.A. 33111  10.5000    NaN
# 803  male   0.42               0           1        2625   8.5167    NaN
# 80   male  22.00               0           0      345767   9.0000    NaN
#
#     Embarque
# 630        S
# 70         S
# 803        C
# 80         S

# %%
data.iloc[2:8]
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
# 5             6           0       3
# 6             7           0       1
# 7             8           0       3
#
#                                            Nome    Sexo  Idade  \
# 2                        Heikkinen, Miss. Laina  female   26.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                      Allen, Mr. William Henry    male   35.0
# 5                              Moran, Mr. James    male    NaN
# 6                       McCarthy, Mr. Timothy J    male   54.0
# 7                Palsson, Master. Gosta Leonard    male    2.0
#
#    IrmaosConjugue  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 2               0           0  STON/O2. 3101282   7.9250    NaN        S
# 3               1           0            113803  53.1000   C123        S
# 4               0           0            373450   8.0500    NaN        S
# 5               0           0            330877   8.4583    NaN        Q
# 6               0           0             17463  51.8625    E46        S
# 7               3           1            349909  21.0750    NaN        S

# %%
data.iloc[0:3]
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
#
#    IrmaosConjugue  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0               1           0         A/5 21171   7.2500    NaN        S
# 1               1           0          PC 17599  71.2833    C85        C
# 2               0           0  STON/O2. 3101282   7.9250    NaN        S

# %%
data['Nome'].iloc[2]
# Out:
# 'Heikkinen, Miss. Laina'

# %%
data['Idade'].iloc[870]
# Out:
# 26.0

# %% [markdown]
# Loc

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']].loc[data['Idade']== 1]
# Out:
#      Idade    Sexo   Tarifa  Classe  Sobreviveu
# 164    1.0    male  39.6875       3           0
# 172    1.0  female  11.1333       3           1
# 183    1.0    male  39.0000       2           1
# 381    1.0  female  15.7417       3           1
# 386    1.0    male  46.9000       3           0
# 788    1.0    male  20.5750       3           1
# 827    1.0    male  37.0042       2           1

# %%
data[['Idade', 'Sexo', 'Tarifa', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>=3) & (data['Idade']<=10) & ~(data['Sobreviveu']==0)]
# Out:
#      Idade    Sexo   Tarifa  Classe  Sobreviveu
# 10     4.0  female  16.7000       3           1
# 43     3.0  female  41.5792       2           1
# 58     5.0  female  27.7500       2           1
# 165    9.0    male  20.5250       3           1
# 184    4.0  female  22.0250       3           1
# 193    3.0    male  26.0000       2           1
# 233    5.0  female  31.3875       3           1
# 237    8.0  female  26.2500       2           1
# 261    3.0    male  31.3875       3           1
# 348    3.0    male  15.9000       3           1
# 407    3.0    male  18.7500       2           1
# 445    4.0    male  81.8583       1           1
# 448    5.0  female  19.2583       3           1
# 489    9.0    male  15.9000       3           1
# 535    7.0  female  26.2500       2           1
# 549    8.0    male  36.7500       2           1
# 618    4.0  female  39.0000       2           1
# 691    4.0  female  13.4167       3           1
# 720    6.0  female  33.0000       2           1
# 750    4.0  female  23.0000       2           1
# 751    6.0    male  12.4750       3           1
# 777    5.0  female  12.4750       3           1
# 869    4.0    male  11.1333       3           1

# %%
data[['Idade', 'Sexo', 'Classe', 'Sobreviveu']]\
.loc[(data['Idade']>14)\
     & (data['Sobreviveu']==1)\
     & (data['Sexo']=='male')\
    & (data['Classe']==3)].count()
# Out:
# Idade         29
# Sexo          29
# Classe        29
# Sobreviveu    29
# dtype: int64

# %% [markdown]
# Map and Replace

# %%
data['Sexo'].map({'male': 'homem', 'female': 'mulher'}).head()
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}, inplace=True)

# %%
data['Sexo'].replace(['male', 'female'], ['homem', 'mulher']).head(6)
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# 5     homem
# Name: Sexo, dtype: object

# %%
data['Sexo']
# Out:
# 0       homem
# 1      mulher
# 2      mulher
# 3      mulher
# 4       homem
#         ...
# 886     homem
# 887    mulher
# 888    mulher
# 889     homem
# 890     homem
# Name: Sexo, Length: 891, dtype: object

# %% [markdown]
# Groupby

# %%
data.groupby('Sexo').mean()
# Out:
#         IdPassageiro  Sobreviveu    Classe      Idade  IrmaosConjugue  \
# Sexo
# homem     454.147314    0.188908  2.389948  30.726645        0.429809
# mulher    431.028662    0.742038  2.159236  27.915709        0.694268
#
#         PaisFilhos     Tarifa
# Sexo
# homem     0.235702  25.523893
# mulher    0.649682  44.479818

# %%
data.groupby('Sobreviveu').mean()
# Out:
#             IdPassageiro    Classe      Idade  IrmaosConjugue  PaisFilhos  \
# Sobreviveu
# 0             447.016393  2.531876  30.626179        0.553734    0.329690
# 1             444.368421  1.950292  28.343690        0.473684    0.464912
#
#                Tarifa
# Sobreviveu
# 0           22.117887
# 1           48.395408

# %%
data.groupby('Classe').mean()
# Out:
#         IdPassageiro  Sobreviveu      Idade  IrmaosConjugue  PaisFilhos  \
# Classe
# 1         461.597222    0.629630  38.233441        0.416667    0.356481
# 2         445.956522    0.472826  29.877630        0.402174    0.380435
# 3         439.154786    0.242363  25.140620        0.615071    0.393075
#
#            Tarifa
# Classe
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
data.groupby(['Sexo','Classe']).mean()
# Out:
#                IdPassageiro  Sobreviveu      Idade  IrmaosConjugue  \
# Sexo   Classe
# homem  1         455.729508    0.368852  41.281386        0.311475
#        2         447.962963    0.157407  30.740707        0.342593
#        3         455.515850    0.135447  26.507589        0.498559
# mulher 1         469.212766    0.968085  34.611765        0.553191
#        2         443.105263    0.921053  28.722973        0.486842
#        3         399.729167    0.500000  21.750000        0.895833
#
#                PaisFilhos      Tarifa
# Sexo   Classe
# homem  1         0.278689   67.226127
#        2         0.222222   19.741782
#        3         0.224784   12.661633
# mulher 1         0.457447  106.125798
#        2         0.605263   21.970121
#        3         0.798611   16.118810

# %% [markdown]
# Crosstab

# %%
pd.crosstab(data['Sobreviveu'], data['Classe'], margins=True).style.background_gradient(cmap='OrRd')
# Out:
# <style  type="text/css" >
# #T_d0549_row0_col0,#T_d0549_row1_col1,#T_d0549_row1_col2,#T_d0549_row1_col3{
#             background-color:  #fff7ec;
#             color:  #000000;
#         }#T_d0549_row0_col1{
#             background-color:  #feebcf;
#             color:  #000000;
#         }#T_d0549_row0_col2{
#             background-color:  #e44d35;
#             color:  #000000;
#         }#T_d0549_row0_col3{
#             background-color:  #fdba83;
#             color:  #000000;
#         }#T_d0549_row1_col0{
#             background-color:  #fdad77;
#             color:  #000000;
#         }#T_d0549_row2_col0,#T_d0549_row2_col1,#T_d0549_row2_col2,#T_d0549_row2_col3{
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }</style><table id="T_d0549_" ><thead>    <tr>        <th class="index_name level0" >Classe</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sobreviveu</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d0549_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d0549_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_d0549_row0_col1" class="data row0 col1" >97</td>
#                         <td id="T_d0549_row0_col2" class="data row0 col2" >372</td>
#                         <td id="T_d0549_row0_col3" class="data row0 col3" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_d0549_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d0549_row1_col0" class="data row1 col0" >136</td>
#                         <td id="T_d0549_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_d0549_row1_col2" class="data row1 col2" >119</td>
#                         <td id="T_d0549_row1_col3" class="data row1 col3" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_d0549_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_d0549_row2_col0" class="data row2 col0" >216</td>
#                         <td id="T_d0549_row2_col1" class="data row2 col1" >184</td>
#                         <td id="T_d0549_row2_col2" class="data row2 col2" >491</td>
#                         <td id="T_d0549_row2_col3" class="data row2 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
pd.crosstab(data['Sobreviveu'], data['Sexo'], margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_cfb53_row0_col0{
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }#T_cfb53_row0_col1,#T_cfb53_row1_col0,#T_cfb53_row1_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_cfb53_row0_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_cfb53_row1_col1{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_cfb53_row2_col0,#T_cfb53_row2_col1,#T_cfb53_row2_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_cfb53_" ><thead>    <tr>        <th class="index_name level0" >Sexo</th>        <th class="col_heading level0 col0" >homem</th>        <th class="col_heading level0 col1" >mulher</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sobreviveu</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfb53_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cfb53_row0_col0" class="data row0 col0" >468</td>
#                         <td id="T_cfb53_row0_col1" class="data row0 col1" >81</td>
#                         <td id="T_cfb53_row0_col2" class="data row0 col2" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb53_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cfb53_row1_col0" class="data row1 col0" >109</td>
#                         <td id="T_cfb53_row1_col1" class="data row1 col1" >233</td>
#                         <td id="T_cfb53_row1_col2" class="data row1 col2" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb53_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_cfb53_row2_col0" class="data row2 col0" >577</td>
#                         <td id="T_cfb53_row2_col1" class="data row2 col1" >314</td>
#                         <td id="T_cfb53_row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Ordenando Dados

# %%
data[['Idade', 'Sexo', 'Classe', 'Sobreviveu']].sort_values('Idade', ascending=True).head(11)
# Out:
#      Idade    Sexo  Classe  Sobreviveu
# 803   0.42   homem       3           1
# 755   0.67   homem       2           1
# 644   0.75  mulher       3           1
# 469   0.75  mulher       3           1
# 78    0.83   homem       2           1
# 831   0.83   homem       2           1
# 305   0.92   homem       1           1
# 827   1.00   homem       2           1
# 381   1.00  mulher       3           1
# 164   1.00   homem       3           0
# 183   1.00   homem       2           1

# %%
data[['Idade', 'Sexo', 'Classe', 'Sobreviveu']].sort_index(ascending=True)
# Out:
#      Idade    Sexo  Classe  Sobreviveu
# 0     22.0   homem       3           0
# 1     38.0  mulher       1           1
# 2     26.0  mulher       3           1
# 3     35.0  mulher       1           1
# 4     35.0   homem       3           0
# ..     ...     ...     ...         ...
# 886   27.0   homem       2           0
# 887   19.0  mulher       1           1
# 888    NaN  mulher       3           0
# 889   26.0   homem       1           1
# 890   32.0   homem       3           0
#
# [891 rows x 4 columns]

# %% [markdown]
# Lidando com dados faltando

# %%
data.isnull().sum()
# Out:
# IdPassageiro        0
# Sobreviveu          0
# Classe              0
# Nome                0
# Sexo                0
# Idade             177
# IrmaosConjugue      0
# PaisFilhos          0
# Bilhete             0
# Tarifa              0
# Cabine            687
# Embarque            2
# dtype: int64

# %%
data.loc[data['Embarque'].isnull()]
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 61             62           1       1
# 829           830           1       1
#
#                                           Nome    Sexo  Idade  IrmaosConjugue  \
# 61                         Icard, Miss. Amelie  mulher   38.0               0
# 829  Stone, Mrs. George Nelson (Martha Evelyn)  mulher   62.0               0
#
#      PaisFilhos Bilhete  Tarifa Cabine Embarque
# 61            0  113572    80.0    B28      NaN
# 829           0  113572    80.0    B28      NaN

# %%
data['Embarque'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data['Embarque'].mode()
# Out:
# 0    S
# dtype: object

# %%
data.describe()
# Out:
#        IdPassageiro  Sobreviveu      Classe       Idade  IrmaosConjugue  \
# count    891.000000  891.000000  891.000000  714.000000      891.000000
# mean     446.000000    0.383838    2.308642   29.699118        0.523008
# std      257.353842    0.486592    0.836071   14.526497        1.102743
# min        1.000000    0.000000    1.000000    0.420000        0.000000
# 25%      223.500000    0.000000    2.000000   20.125000        0.000000
# 50%      446.000000    0.000000    3.000000   28.000000        0.000000
# 75%      668.500000    1.000000    3.000000   38.000000        1.000000
# max      891.000000    1.000000    3.000000   80.000000        8.000000
#
#        PaisFilhos      Tarifa
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
644/889
# Out:
# 0.7244094488188977

# %%
data['Embarque'].fillna('S').isnull

# %%
data['Embarque'].at[61] = 'S'

# %%
data['Embarque'].at[61]
# Out:
# 'S'

# %% [markdown]
# Deletando COLUNA

# %%
data.isnull().sum()
# Out:
# IdPassageiro        0
# Sobreviveu          0
# Classe              0
# Nome                0
# Sexo                0
# Idade             177
# IrmaosConjugue      0
# PaisFilhos          0
# Bilhete             0
# Tarifa              0
# Embarque            1
# dtype: int64

# %%
data.drop('Cabine', axis=1, inplace=True)

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris   homem   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                             Heikkinen, Miss. Laina  mulher   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                           Allen, Mr. William Henry   homem   35.0
#
#    IrmaosConjugue  PaisFilhos           Bilhete   Tarifa Embarque
# 0               1           0         A/5 21171   7.2500        S
# 1               1           0          PC 17599  71.2833        C
# 2               0           0  STON/O2. 3101282   7.9250        S
# 3               1           0            113803  53.1000        S
# 4               0           0            373450   8.0500        S

# %%
data.drop(0)
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# 5               6           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                               Heikkinen, Miss. Laina  mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                             Allen, Mr. William Henry   homem   35.0
# 5                                     Moran, Mr. James   homem    NaN
# ..                                                 ...     ...    ...
# 886                              Montvila, Rev. Juozas   homem   27.0
# 887                       Graham, Miss. Margaret Edith  mulher   19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  mulher    NaN
# 889                              Behr, Mr. Karl Howell   homem   26.0
# 890                                Dooley, Mr. Patrick   homem   32.0
#
#      IrmaosConjugue  PaisFilhos           Bilhete   Tarifa Embarque
# 1                 1           0          PC 17599  71.2833        C
# 2                 0           0  STON/O2. 3101282   7.9250        S
# 3                 1           0            113803  53.1000        S
# 4                 0           0            373450   8.0500        S
# 5                 0           0            330877   8.4583        Q
# ..              ...         ...               ...      ...      ...
# 886               0           0            211536  13.0000        S
# 887               0           0            112053  30.0000        S
# 888               1           2        W./C. 6607  23.4500        S
# 889               0           0            111369  30.0000        C
# 890               0           0            370376   7.7500        Q
#
# [890 rows x 11 columns]

# %% [markdown]
# Apply and Lambda

# %%
data['Idade'].apply(lambda x: x**2).head(26)
# Out:
# 0      484.0
# 1     1444.0
# 2      676.0
# 3     1225.0
# 4     1225.0
# 5        NaN
# 6     2916.0
# 7        4.0
# 8      729.0
# 9      196.0
# 10      16.0
# 11    3364.0
# 12     400.0
# 13    1521.0
# 14     196.0
# 15    3025.0
# 16       4.0
# 17       NaN
# 18     961.0
# 19       NaN
# 20    1225.0
# 21    1156.0
# 22     225.0
# 23     784.0
# 24      64.0
# 25    1444.0
# Name: Idade, dtype: float64

# %%
data['Bilhete']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Bilhete, Length: 891, dtype: object

# %%
data['Bilhete'] = data['Bilhete'].apply(lambda x: x[:-1])

# %%
data['Bilhete']
# Out:
# 0             A/5 2117
# 1              PC 1759
# 2      STON/O2. 310128
# 3                11380
# 4                37345
#             ...
# 886              21153
# 887              11205
# 888          W./C. 660
# 889              11136
# 890              37037
# Name: Bilhete, Length: 891, dtype: object

# %% [markdown]
# Variáveis Dummy | HotEncoder

# %%
data= pd.get_dummies(data, columns=['Sexo'], drop_first=True)

# %%
embarque = pd.get_dummies(data['Embarque'], drop_first=True)

# %%
embarque.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
data.head()
# Out:
#    IdPassageiro  Sobreviveu  Classe  \
# 0             1           0       3
# 1             2           1       1
# 2             3           1       3
# 3             4           1       1
# 4             5           0       3
#
#                                                 Nome  Idade  IrmaosConjugue  \
# 0                            Braund, Mr. Owen Harris   22.0               1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0               1
# 2                             Heikkinen, Miss. Laina   26.0               0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0               1
# 4                           Allen, Mr. William Henry   35.0               0
#
#    PaisFilhos          Bilhete   Tarifa Embarque  Sexo_mulher
# 0           0         A/5 2117   7.2500        S            0
# 1           0          PC 1759  71.2833        C            1
# 2           0  STON/O2. 310128   7.9250        S            1
# 3           0            11380  53.1000        S            1
# 4           0            37345   8.0500        S            0

# %%
data.shape, embarque.shape
# Out:
# ((891, 11), (891, 2))

# %%
data= pd.concat([data, embarque], axis=1)

# %%
data.shape
# Out:
# (891, 13)

# %%
data.drop('Embarque', axis=1, inplace=True)

# %%
data
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome  Idade  IrmaosConjugue  \
# 0                              Braund, Mr. Owen Harris   22.0               1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0               1
# 2                               Heikkinen, Miss. Laina   26.0               0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0               1
# 4                             Allen, Mr. William Henry   35.0               0
# ..                                                 ...    ...             ...
# 886                              Montvila, Rev. Juozas   27.0               0
# 887                       Graham, Miss. Margaret Edith   19.0               0
# 888           Johnston, Miss. Catherine Helen "Carrie"    NaN               1
# 889                              Behr, Mr. Karl Howell   26.0               0
# 890                                Dooley, Mr. Patrick   32.0               0
#
#      PaisFilhos          Bilhete   Tarifa  Sexo_mulher  Q  S
# 0             0         A/5 2117   7.2500            0  0  1
# 1             0          PC 1759  71.2833            1  0  0
# 2             0  STON/O2. 310128   7.9250            1  0  1
# 3             0            11380  53.1000            1  0  1
# 4             0            37345   8.0500            0  0  1
# ..          ...              ...      ...          ... .. ..
# 886           0            21153  13.0000            0  0  1
# 887           0            11205  30.0000            1  0  1
# 888           2        W./C. 660  23.4500            1  0  1
# 889           0            11136  30.0000            0  0  0
# 890           0            37037   7.7500            0  1  0
#
# [891 rows x 12 columns]

# %% [markdown]
# Expressões Regulares

# %%
data['Titulo'] = data['Nome'].str.extract('([a-zA-Z]+)\.')

# %%
data
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome  Idade  IrmaosConjugue  \
# 0                              Braund, Mr. Owen Harris   22.0               1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   38.0               1
# 2                               Heikkinen, Miss. Laina   26.0               0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   35.0               1
# 4                             Allen, Mr. William Henry   35.0               0
# ..                                                 ...    ...             ...
# 886                              Montvila, Rev. Juozas   27.0               0
# 887                       Graham, Miss. Margaret Edith   19.0               0
# 888           Johnston, Miss. Catherine Helen "Carrie"    NaN               1
# 889                              Behr, Mr. Karl Howell   26.0               0
# 890                                Dooley, Mr. Patrick   32.0               0
#
#      PaisFilhos          Bilhete   Tarifa  Sexo_mulher  Q  S Titulo
# 0             0         A/5 2117   7.2500            0  0  1     Mr
# 1             0          PC 1759  71.2833            1  0  0    Mrs
# 2             0  STON/O2. 310128   7.9250            1  0  1   Miss
# 3             0            11380  53.1000            1  0  1    Mrs
# 4             0            37345   8.0500            0  0  1     Mr
# ..          ...              ...      ...          ... .. ..    ...
# 886           0            21153  13.0000            0  0  1    Rev
# 887           0            11205  30.0000            1  0  1   Miss
# 888           2        W./C. 660  23.4500            1  0  1   Miss
# 889           0            11136  30.0000            0  0  0     Mr
# 890           0            37037   7.7500            0  1  0     Mr
#
# [891 rows x 13 columns]

# %% [markdown]
# Feature Engineering - Melhorando

# %%
data['Sexo'] = data['Sexo_mulher'].map({0: 'homem', 1: 'mulher'})

# %%
pd.crosstab(data['Titulo'], data['Sexo'])
# Out:
# Sexo    homem  mulher
# Titulo
# Master     40       0
# Miss        0     182
# Mr        517       0
# Mrs         0     125
# Outros     20       7

# %%
data['Titulo'] = data['Titulo'].apply(lambda x:'Outros' if x not in ['Master', 'Miss', 'Mr', 'Mrs'] else x)

# %%
data[['Titulo', 'Sexo', 'Idade', 'Classe', 'Sobreviveu']].loc[data['Titulo']=='Master'].mean()
# Out:
# Idade         4.574167
# Classe        2.625000
# Sobreviveu    0.575000
# dtype: float64

# %% [markdown]
# Iterrows

# %%
cabine = pd.read_csv('train.csv')

# %%
cabine['Cabin'].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
for idx, _ in data['Cabin'].dropna()
# Out:
#   File "<ipython-input-219-efdd701fc2ac>", line 1
#     for idx, _ in data['Cabin'].dropna()
#                                         ^
# SyntaxError: invalid syntax

# %%
cabine['Cabin'].dropna().head(51)
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
# 151             C2
# 166            E33
# 170            B19
# 174             A7
# 177            C49
# 183             F4
# 185            A32
# 193             F2
# 194             B4
# 195            B80
# 205             G6
# 209            A31
# 215            D36
# 218            D15
# 224            C93
# 230            C83
# 245            C78
# 248            D35
# 251             G6
# 252            C87
# 257            B77
# Name: Cabin, dtype: object

# %%
cabine['Cabin'].shape
# Out:
# (891,)

# %%
for idx, _ in cabine['Cabin'].dropna().iterrows():
    cabine-individual= cabine['Cabin'].at[idx]
    cabine['Cabin'].at[idx]= cabine_individual[0]
# Out:
#   File "<ipython-input-228-73a557477378>", line 2
#     cabine-individual= cabine['Cabin'].at[idx]
#     ^
# SyntaxError: cannot assign to operator

# %%
a='C85'

# %%
cabine[['Cabin']].dropna()
# Out:
#            Cabin
# 1            C85
# 3           C123
# 6            E46
# 10            G6
# 11          C103
# ..           ...
# 871          D35
# 872  B51 B53 B55
# 879          C50
# 887          B42
# 889         C148
#
# [204 rows x 1 columns]

# %%
cabine[['Cabin','Survived', 'Sex', 'Pclass']].dropna().groupby(['Cabin', 'Sex']).mean()
# Out:
#               Survived  Pclass
# Cabin Sex
# A10   male         0.0     1.0
# A14   male         0.0     1.0
# A16   female       1.0     1.0
# A19   male         0.0     1.0
# A20   male         1.0     1.0
# ...                ...     ...
# F38   male         0.0     3.0
# F4    female       1.0     2.0
#       male         1.0     2.0
# G6    female       0.5     3.0
# T     male         0.0     1.0
#
# [171 rows x 2 columns]

# %%
cabine.loc[cabine['Cabin']=='T']
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 339          340         0       1  Blackwell, Mr. Stephen Weart  male  45.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 339      0      0  113784  35.5     T        S
